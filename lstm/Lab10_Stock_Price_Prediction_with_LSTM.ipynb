# %%
import pandas as pd
import datetime
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
import argparse
from copy import deepcopy # Add Deepcopy for args
from sklearn.metrics import mean_absolute_error

import seaborn as sns
import matplotlib.pyplot as plt

print(torch.__version__)
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 9)
# Out:
# 1.7.1
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Loading Dataset Test

# %%
DATASET_PATH = '/home/greenstar/sensorcloud/LSTM-playground/coin_desk_data.csv'

coin = pd.read_csv(DATASET_PATH)
coin = coin.set_index('Timestamp')
coin
# Out:
#                    Close          Open          High           Low
# Timestamp
# 2013-10-01    123.654990    124.304660    124.751660    122.563490
# 2013-10-02    125.455000    123.654990    125.758500    123.633830
# 2013-10-03    108.584830    125.455000    125.665660     83.328330
# 2013-10-04    118.674660    108.584830    118.675000    107.058160
# 2013-10-05    121.338660    118.674660    121.936330    118.005660
# ...                  ...           ...           ...           ...
# 2021-01-08  39713.507857  36806.419755  40324.014033  36356.430756
# 2021-01-09  40519.448598  39420.800696  41962.362125  36741.330177
# 2021-01-10  40258.923989  40558.102123  41375.430681  38766.276161
# 2021-01-11  38709.765375  40096.333202  41186.523430  34897.550466
# 2021-01-12  34409.642375  38132.535794  38204.754410  30305.300045
#
# [2651 rows x 4 columns]

# %%
coin.Close.plot(grid=True)
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
coin.tail()
print(coin.isna().sum())
# Out:
# Close    0
# Open     0
# High     0
# Low      0
# dtype: int64

# %% [markdown]
# # Data Preparation

# %%
class CoinDataset(Dataset):
    def __init__(self, csv_path, x_frames, y_frames, start, end):
        self.x_frames = x_frames
        self.y_frames = y_frames

        _time_start = datetime.datetime(*start)
        _time_end = datetime.datetime(*end)
        _start = _time_start.strftime('%Y-%m-%d')
        _end = _time_end.strftime('%Y-%m-%d')

        _data = pd.read_csv(csv_path)
        _data = _data.set_index('Timestamp')
        _data = _data[_start:_end]
        self.data = _data

        #print(self.data.isna().sum())
        print(len(self.data))
        
    def __len__(self):
        return len(self.data) - (self.x_frames + self.y_frames) + 1
    
    def __getitem__(self, idx):
        idx += self.x_frames
        data = self.data.iloc[idx-self.x_frames:idx+self.y_frames]
        data = data[['Close', 'Open', 'High', 'Low']]
        data = data.apply(lambda x: np.log(x+1) - np.log(x[self.x_frames-1]+1))
        data = data.values
        X = data[:self.x_frames]
        y = data[self.x_frames:]
        
        return X, y

# %%
# Model Define
class LSTM(nn.Module):
    
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers, batch_size, dropout, use_bn):
        super(LSTM, self).__init__()
        self.input_dim = input_dim 
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        self.num_layers = num_layers

        self.batch_size = batch_size
        self.dropout = dropout
        self.use_bn = use_bn 
        
        self.lstm = nn.LSTM(self.input_dim, self.hidden_dim, self.num_layers)
        self.hidden = self.init_hidden()
        self.regressor = self.make_regressor()
        
    def init_hidden(self):
        return (torch.zeros(self.num_layers, self.batch_size, self.hidden_dim),
                torch.zeros(self.num_layers, self.batch_size, self.hidden_dim))
    
    def make_regressor(self):
        layers = []
        if self.use_bn:
            layers.append(nn.BatchNorm1d(self.hidden_dim))
        layers.append(nn.Dropout(self.dropout))
        
        layers.append(nn.Linear(self.hidden_dim, self.hidden_dim // 2))
        layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim // 2, self.output_dim))
        regressor = nn.Sequential(*layers)
        return regressor
    
    def forward(self, x):
        lstm_out, self.hidden = self.lstm(x, self.hidden)
        y_pred = self.regressor(lstm_out[-1].view(self.batch_size, -1))
        return y_pred

# %%
def metric(y_pred, y_true):
    perc_y_pred = np.exp(y_pred.cpu().detach().numpy())
    perc_y_true = np.exp(y_true.cpu().detach().numpy())
    mae = mean_absolute_error(perc_y_true, perc_y_pred, multioutput='raw_values')
    return mae*100

# %% [markdown]
# # Train, Validate, Test

# %%
def train(model, partition, optimizer, loss_fn, args):
    trainloader = DataLoader(partition['train'], 
                             batch_size=args.batch_size, 
                             shuffle=True, drop_last=True)
    model.train()
    model.zero_grad()
    optimizer.zero_grad()

    train_acc = 0.0
    train_loss = 0.0
    for i, (X, y) in enumerate(trainloader):

        X = X.transpose(0, 1).float().to(args.device)
        y_true = y[:, :, 0].float().to(args.device)
        #print(torch.max(X[:, :, 3]), torch.max(y_true))

        model.zero_grad()
        optimizer.zero_grad()
        model.hidden = [hidden.to(args.device) for hidden in model.init_hidden()]

        y_pred = model(X)
        loss = loss_fn(y_pred.view(-1), y_true.view(-1))
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_acc += metric(y_pred, y_true)[0]

    train_loss = train_loss / len(trainloader)
    train_acc = train_acc / len(trainloader)
    return model, train_loss, train_acc

# %%
def validate(model, partition, loss_fn, args):
    valloader = DataLoader(partition['val'], 
                           batch_size=args.batch_size, 
                           shuffle=False, drop_last=True)
    model.eval()

    val_acc = 0.0
    val_loss = 0.0
    with torch.no_grad():
        for i, (X, y) in enumerate(valloader):

            X = X.transpose(0, 1).float().to(args.device)
            y_true = y[:, :, 0].float().to(args.device)
            model.hidden = [hidden.to(args.device) for hidden in model.init_hidden()]

            y_pred = model(X)
            loss = loss_fn(y_pred.view(-1), y_true.view(-1))

            val_loss += loss.item()
            val_acc += metric(y_pred, y_true)[0]

    val_loss = val_loss / len(valloader)
    val_acc = val_acc / len(valloader)
    return val_loss, val_acc

# %%
def test(model, partition, args):
    testloader = DataLoader(partition['test'], 
                           batch_size=args.batch_size, 
                           shuffle=False, drop_last=True)
    model.eval()

    test_acc = 0.0
    with torch.no_grad():
        for i, (X, y) in enumerate(testloader):

            X = X.transpose(0, 1).float().to(args.device)
            y_true = y[:, :, 0].float().to(args.device)
            model.hidden = [hidden.to(args.device) for hidden in model.init_hidden()]

            y_pred = model(X)
            #print(f'y_pred: {y_pred}')
            test_acc += metric(y_pred, y_true)[0]

    test_acc = test_acc / len(testloader)
    return test_acc

# %%
def experiment(partition, args):

    model = LSTM(args.input_dim, args.hid_dim, args.y_frames, args.n_layers, args.batch_size, args.dropout, args.use_bn)
    model.to(args.device)
    loss_fn = torch.nn.MSELoss()

    loss_fn = nn.MSELoss()
    if args.optim == 'SGD':
        optimizer = optim.RMSprop(model.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.l2)
    else:
        raise ValueError('In-valid optimizer choice')
    
    # ===== List for epoch-wise data ====== #
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []
    # ===================================== #
        
    for epoch in range(args.epoch):  # loop over the dataset multiple times
        ts = time.time()
        model, train_loss, train_acc = train(model, partition, optimizer, loss_fn, args)
        val_loss, val_acc = validate(model, partition, loss_fn, args)
        te = time.time()
        
        # ====== Add Epoch Data ====== #
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        # ============================ #
        
        print('Epoch {}, Acc(train/val): {:2.2f}/{:2.2f}, Loss(train/val) {:2.5f}/{:2.5f}. Took {:2.2f} sec'.format(epoch, train_acc, val_acc, train_loss, val_loss, te-ts))
        
    test_acc = test(model, partition, args)    
    
    # ======= Add Result to Dictionary ======= #
    result = {}
    result['train_losses'] = train_losses
    result['val_losses'] = val_losses
    result['train_accs'] = train_accs
    result['val_accs'] = val_accs
    result['train_acc'] = train_acc
    result['val_acc'] = val_acc
    result['test_acc'] = test_acc

    # ======= Save Model Data ======= #
    SAVE_PATH = './models/test2.tar'
    torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'args': args,
            'result': result
            }, SAVE_PATH)

    return vars(args), result

# %% [markdown]
# # Manage Experiment

# %%
import hashlib
import json
from os import listdir
from os.path import isfile, join
import pandas as pd

def save_exp_result(setting, result):
    exp_name = setting['exp_name']
    del setting['epoch']

    hash_key = hashlib.sha1(str(setting).encode()).hexdigest()[:6]
    filename = './results/{}-{}.json'.format(exp_name, hash_key)
    result.update(setting)
    with open(filename, 'w') as f:
        json.dump(result, f)

    
def load_exp_result(exp_name):
    dir_path = './results'
    filenames = [f for f in listdir(dir_path) if isfile(join(dir_path, f)) if '.json' in f]
    list_result = []
    for filename in filenames:
        if exp_name in filename:
            with open(join(dir_path, filename), 'r') as infile:
                results = json.load(infile)
                list_result.append(results)
    df = pd.DataFrame(list_result) # .drop(columns=[])
    return df

# %%
def plot_acc(var1, var2, df):

    fig, ax = plt.subplots(1, 3)
    fig.set_size_inches(15, 6)
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})

    sns.barplot(x=var1, y='train_acc', hue=var2, data=df, ax=ax[0])
    sns.barplot(x=var1, y='val_acc', hue=var2, data=df, ax=ax[1])
    sns.barplot(x=var1, y='test_acc', hue=var2, data=df, ax=ax[2])
    
    ax[0].set_title('Train Accuracy')
    ax[1].set_title('Validation Accuracy')
    ax[2].set_title('Test Accuracy')

    
def plot_loss_variation(var1, var2, df, **kwargs):

    list_v1 = df[var1].unique()
    list_v2 = df[var2].unique()
    list_data = []

    for value1 in list_v1:
        for value2 in list_v2:
            row = df.loc[df[var1]==value1]
            row = row.loc[df[var2]==value2]

            train_losses = list(row.train_losses)[0]
            val_losses = list(row.val_losses)[0]

            for epoch, train_loss in enumerate(train_losses):
                list_data.append({'type':'train', 'loss':train_loss, 'epoch':epoch, var1:value1, var2:value2})
            for epoch, val_loss in enumerate(val_losses):
                list_data.append({'type':'val', 'loss':val_loss, 'epoch':epoch, var1:value1, var2:value2})

    df = pd.DataFrame(list_data)
    g = sns.FacetGrid(df, row=var2, col=var1, hue='type', **kwargs)
    g = g.map(plt.plot, 'epoch', 'loss', marker='.')
    g.add_legend()
    g.fig.suptitle('Train loss vs Val loss')
    plt.subplots_adjust(top=0.89) # 만약 Title이 그래프랑 겹친다면 top 값을 조정해주면 됩니다! 함수 인자로 받으면 그래프마다 조절할 수 있겠죠?


def plot_acc_variation(var1, var2, df, **kwargs):
    list_v1 = df[var1].unique()
    list_v2 = df[var2].unique()
    list_data = []

    for value1 in list_v1:
        for value2 in list_v2:
            row = df.loc[df[var1]==value1]
            row = row.loc[df[var2]==value2]

            train_accs = list(row.train_accs)[0]
            val_accs = list(row.val_accs)[0]
            test_acc = list(row.test_acc)[0]

            for epoch, train_acc in enumerate(train_accs):
                list_data.append({'type':'train', 'Acc':train_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
            for epoch, val_acc in enumerate(val_accs):
                list_data.append({'type':'val', 'Acc':val_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})

    df = pd.DataFrame(list_data)
    g = sns.FacetGrid(df, row=var2, col=var1, hue='type', **kwargs)
    g = g.map(plt.plot, 'epoch', 'Acc', marker='.')

    def show_acc(x, y, metric, **kwargs):
        plt.scatter(x, y, alpha=0.3, s=1)
        metric = "Test Acc: {:1.3f}".format(list(metric.values)[0])
        plt.text(0.05, 0.95, metric,  horizontalalignment='left', verticalalignment='center', transform=plt.gca().transAxes, bbox=dict(facecolor='yellow', alpha=0.5, boxstyle="round,pad=0.1"))
    g = g.map(show_acc, 'epoch', 'Acc', 'test_acc')

    g.add_legend()
    g.fig.suptitle('Train Accuracy vs Val Accuracy')
    plt.subplots_adjust(top=0.89)

# %%
# ====== Random Seed Initialization ====== #
seed = 666
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")
args.exp_name = "exp4"
args.device = 'cuda' if torch.cuda.is_available() else 'cpu'

# ====== Data Loading ====== #
args.csv_path = '/home/greenstar/sensorcloud/LSTM-playground/coin_desk_data.csv'
args.batch_size = 128
args.x_frames = 64
args.y_frames = 8

# ====== Model Capacity ===== #
args.input_dim = 4
args.hid_dim = 50
args.n_layers = 2

# ====== Regularization ======= #
args.l2 = 0.00001
args.dropout = 0.0
args.use_bn = True

# ====== Optimizer & Training ====== #
args.optim = 'Adam' #'RMSprop' #SGD, RMSprop, Adam...
args.lr = 0.0001
args.epoch = 100


# ====== Experiment Variable ====== #
name_var1 = 'lr'
name_var2 = 'n_layers'
list_var1 = [0.0001] # [0.001, 0.0001, 0.00001]
list_var2 = [4]


# ====== Dataset Prep ====== #
trainset = CoinDataset(args.csv_path, args.x_frames, args.y_frames, (2013,10,1), (2018,10,1))
valset = CoinDataset(args.csv_path, args.x_frames, args.y_frames, (2018,10,1), (2020,1,1))
testset = CoinDataset(args.csv_path, args.x_frames, args.y_frames, (2020,1,1), (2021,1,12))
partition = {'train': trainset, 'val':valset, 'test':testset}


for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1)
        setattr(args, name_var2, var2)
        print(args)
                
        setting, result = experiment(partition, deepcopy(args))
        save_exp_result(setting, result)
# Out:
# 1820
# 455
# 378
# Namespace(batch_size=128, csv_path='/home/greenstar/sensorcloud/LSTM-playground/coin_desk_data.csv', device='cuda', dropout=0.0, epoch=100, exp_name='exp4', hid_dim=50, input_dim=4, l2=1e-05, lr=0.0001, n_layers=4, optim='Adam', use_bn=True, x_frames=64, y_frames=8)
# Epoch 0, Acc(train/val): 5.89/5.74, Loss(train/val) 0.01322/0.01109. Took 4.34 sec
# Epoch 1, Acc(train/val): 5.55/5.27, Loss(train/val) 0.01264/0.01076. Took 4.33 sec
# Epoch 2, Acc(train/val): 5.25/4.92, Loss(train/val) 0.01225/0.01045. Took 4.36 sec
# Epoch 3, Acc(train/val): 5.00/4.65, Loss(train/val) 0.01196/0.01021. Took 4.33 sec
# Epoch 4, Acc(train/val): 4.81/4.45, Loss(train/val) 0.01162/0.01002. Took 4.33 sec
# Epoch 5, Acc(train/val): 4.66/4.36, Loss(train/val) 0.01142/0.00994. Took 4.36 sec
# Epoch 6, Acc(train/val): 4.54/4.25, Loss(train/val) 0.01120/0.00985. Took 4.37 sec
# Epoch 7, Acc(train/val): 4.42/4.42, Loss(train/val) 0.01097/0.00984. Took 4.37 sec
# Epoch 8, Acc(train/val): 4.31/4.35, Loss(train/val) 0.01076/0.00930. Took 4.42 sec
# Epoch 9, Acc(train/val): 4.21/3.67, Loss(train/val) 0.01059/0.00885. Took 4.47 sec
# Epoch 10, Acc(train/val): 4.06/4.31, Loss(train/val) 0.01036/0.00857. Took 4.38 sec
# Epoch 11, Acc(train/val): 4.01/4.53, Loss(train/val) 0.01018/0.00837. Took 4.37 sec
# Epoch 12, Acc(train/val): 3.93/5.66, Loss(train/val) 0.00996/0.00834. Took 4.38 sec
# Epoch 13, Acc(train/val): 3.86/8.16, Loss(train/val) 0.00963/0.00857. Took 4.37 sec
# Epoch 14, Acc(train/val): 3.82/8.69, Loss(train/val) 0.00951/0.00878. Took 4.39 sec
# Epoch 15, Acc(train/val): 3.76/9.36, Loss(train/val) 0.00928/0.00889. Took 4.36 sec
# Epoch 16, Acc(train/val): 3.67/7.81, Loss(train/val) 0.00894/0.00851. Took 4.34 sec
# Epoch 17, Acc(train/val): 3.61/4.29, Loss(train/val) 0.00868/0.00943. Took 4.35 sec
# Epoch 18, Acc(train/val): 3.56/3.01, Loss(train/val) 0.00860/0.00820. Took 4.44 sec
# Epoch 19, Acc(train/val): 3.50/2.88, Loss(train/val) 0.00842/0.00745. Took 4.36 sec
# Epoch 20, Acc(train/val): 3.42/2.81, Loss(train/val) 0.00834/0.00723. Took 4.34 sec
# Epoch 21, Acc(train/val): 3.38/3.04, Loss(train/val) 0.00834/0.00787. Took 4.34 sec
# Epoch 22, Acc(train/val): 3.32/2.54, Loss(train/val) 0.00818/0.00698. Took 4.34 sec
# Epoch 23, Acc(train/val): 3.19/2.63, Loss(train/val) 0.00804/0.00654. Took 4.34 sec
# Epoch 24, Acc(train/val): 3.13/2.58, Loss(train/val) 0.00791/0.00666. Took 4.34 sec
# Epoch 25, Acc(train/val): 3.09/3.13, Loss(train/val) 0.00778/0.00667. Took 4.34 sec
# Epoch 26, Acc(train/val): 3.05/2.60, Loss(train/val) 0.00780/0.00640. Took 4.36 sec
# Epoch 27, Acc(train/val): 3.03/2.53, Loss(train/val) 0.00785/0.00647. Took 4.34 sec
# Epoch 28, Acc(train/val): 3.02/2.53, Loss(train/val) 0.00767/0.00628. Took 4.34 sec
# Epoch 29, Acc(train/val): 3.00/2.51, Loss(train/val) 0.00780/0.00634. Took 4.34 sec
# Epoch 30, Acc(train/val): 2.96/2.60, Loss(train/val) 0.00761/0.00615. Took 4.33 sec
# Epoch 31, Acc(train/val): 2.91/2.60, Loss(train/val) 0.00766/0.00619. Took 4.34 sec
# Epoch 32, Acc(train/val): 2.92/2.59, Loss(train/val) 0.00757/0.00619. Took 4.34 sec
# Epoch 33, Acc(train/val): 2.93/3.01, Loss(train/val) 0.00762/0.00609. Took 4.36 sec
# Epoch 34, Acc(train/val): 2.87/3.40, Loss(train/val) 0.00752/0.00629. Took 4.32 sec
# Epoch 35, Acc(train/val): 2.87/2.75, Loss(train/val) 0.00747/0.00611. Took 4.32 sec
# Epoch 36, Acc(train/val): 2.87/3.02, Loss(train/val) 0.00739/0.00596. Took 4.32 sec
# Epoch 37, Acc(train/val): 2.83/2.79, Loss(train/val) 0.00736/0.00624. Took 4.34 sec
# Epoch 38, Acc(train/val): 2.80/2.59, Loss(train/val) 0.00736/0.00605. Took 4.33 sec
# Epoch 39, Acc(train/val): 2.84/2.61, Loss(train/val) 0.00739/0.00605. Took 4.33 sec
# Epoch 40, Acc(train/val): 2.81/2.71, Loss(train/val) 0.00741/0.00596. Took 4.34 sec
# Epoch 41, Acc(train/val): 2.83/2.59, Loss(train/val) 0.00741/0.00595. Took 4.33 sec
# Epoch 42, Acc(train/val): 2.82/3.15, Loss(train/val) 0.00734/0.00609. Took 4.35 sec
# Epoch 43, Acc(train/val): 2.82/2.82, Loss(train/val) 0.00741/0.00610. Took 4.33 sec
# Epoch 44, Acc(train/val): 2.78/2.65, Loss(train/val) 0.00724/0.00608. Took 4.32 sec
# Epoch 45, Acc(train/val): 2.81/2.57, Loss(train/val) 0.00738/0.00587. Took 4.32 sec
# Epoch 46, Acc(train/val): 2.80/3.21, Loss(train/val) 0.00727/0.00621. Took 4.34 sec
# Epoch 47, Acc(train/val): 2.77/2.69, Loss(train/val) 0.00726/0.00605. Took 4.33 sec
# Epoch 48, Acc(train/val): 2.80/2.82, Loss(train/val) 0.00733/0.00627. Took 4.33 sec
# Epoch 49, Acc(train/val): 2.77/2.64, Loss(train/val) 0.00724/0.00598. Took 4.32 sec
# Epoch 50, Acc(train/val): 2.80/2.70, Loss(train/val) 0.00724/0.00595. Took 4.32 sec
# Epoch 51, Acc(train/val): 2.78/2.94, Loss(train/val) 0.00724/0.00609. Took 4.32 sec
# Epoch 52, Acc(train/val): 2.81/2.61, Loss(train/val) 0.00730/0.00607. Took 4.32 sec
# Epoch 53, Acc(train/val): 2.78/2.64, Loss(train/val) 0.00720/0.00595. Took 4.34 sec
# Epoch 54, Acc(train/val): 2.81/2.70, Loss(train/val) 0.00714/0.00611. Took 4.33 sec
# Epoch 55, Acc(train/val): 2.80/2.70, Loss(train/val) 0.00726/0.00584. Took 4.32 sec
# Epoch 56, Acc(train/val): 2.78/2.90, Loss(train/val) 0.00715/0.00615. Took 4.33 sec
# Epoch 57, Acc(train/val): 2.79/2.56, Loss(train/val) 0.00718/0.00636. Took 4.32 sec
# Epoch 58, Acc(train/val): 2.78/2.69, Loss(train/val) 0.00719/0.00593. Took 4.32 sec
# Epoch 59, Acc(train/val): 2.76/2.62, Loss(train/val) 0.00719/0.00603. Took 4.33 sec
# Epoch 60, Acc(train/val): 2.77/2.80, Loss(train/val) 0.00709/0.00616. Took 4.34 sec
# Epoch 61, Acc(train/val): 2.77/2.82, Loss(train/val) 0.00715/0.00603. Took 4.34 sec
# Epoch 62, Acc(train/val): 2.76/2.66, Loss(train/val) 0.00717/0.00586. Took 4.31 sec
# Epoch 63, Acc(train/val): 2.78/2.67, Loss(train/val) 0.00705/0.00590. Took 4.32 sec
# Epoch 64, Acc(train/val): 2.77/2.64, Loss(train/val) 0.00717/0.00590. Took 4.32 sec
# Epoch 65, Acc(train/val): 2.71/2.72, Loss(train/val) 0.00712/0.00592. Took 4.32 sec
# Epoch 66, Acc(train/val): 2.78/2.68, Loss(train/val) 0.00722/0.00617. Took 4.32 sec
# Epoch 67, Acc(train/val): 2.75/2.92, Loss(train/val) 0.00714/0.00601. Took 4.34 sec
# Epoch 68, Acc(train/val): 2.77/2.59, Loss(train/val) 0.00712/0.00582. Took 4.31 sec
# Epoch 69, Acc(train/val): 2.76/2.63, Loss(train/val) 0.00708/0.00588. Took 4.31 sec
# Epoch 70, Acc(train/val): 2.76/2.72, Loss(train/val) 0.00722/0.00602. Took 4.31 sec
# Epoch 71, Acc(train/val): 2.76/2.64, Loss(train/val) 0.00707/0.00600. Took 4.31 sec
# Epoch 72, Acc(train/val): 2.74/2.70, Loss(train/val) 0.00708/0.00589. Took 4.32 sec
# Epoch 73, Acc(train/val): 2.80/2.62, Loss(train/val) 0.00718/0.00687. Took 4.32 sec
# Epoch 74, Acc(train/val): 2.78/2.68, Loss(train/val) 0.00720/0.00586. Took 4.33 sec
# Epoch 75, Acc(train/val): 2.75/2.60, Loss(train/val) 0.00712/0.00607. Took 4.32 sec
# Epoch 76, Acc(train/val): 2.73/2.66, Loss(train/val) 0.00703/0.00612. Took 4.32 sec
# Epoch 77, Acc(train/val): 2.77/2.77, Loss(train/val) 0.00715/0.00594. Took 4.31 sec
# Epoch 78, Acc(train/val): 2.81/2.70, Loss(train/val) 0.00714/0.00615. Took 4.31 sec
# Epoch 79, Acc(train/val): 2.76/2.62, Loss(train/val) 0.00707/0.00597. Took 4.31 sec
# Epoch 80, Acc(train/val): 2.76/2.67, Loss(train/val) 0.00711/0.00589. Took 4.32 sec
# Epoch 81, Acc(train/val): 2.76/2.70, Loss(train/val) 0.00714/0.00594. Took 4.33 sec
# Epoch 82, Acc(train/val): 2.79/2.87, Loss(train/val) 0.00710/0.00607. Took 4.32 sec
# Epoch 83, Acc(train/val): 2.75/2.85, Loss(train/val) 0.00714/0.00590. Took 4.33 sec
# Epoch 84, Acc(train/val): 2.76/2.58, Loss(train/val) 0.00713/0.00587. Took 4.32 sec
# Epoch 85, Acc(train/val): 2.78/2.60, Loss(train/val) 0.00709/0.00605. Took 4.34 sec
# Epoch 86, Acc(train/val): 2.77/2.64, Loss(train/val) 0.00710/0.00593. Took 4.33 sec
# Epoch 87, Acc(train/val): 2.77/2.63, Loss(train/val) 0.00707/0.00589. Took 4.32 sec
# Epoch 88, Acc(train/val): 2.75/3.03, Loss(train/val) 0.00707/0.00594. Took 4.33 sec
# Epoch 89, Acc(train/val): 2.75/2.87, Loss(train/val) 0.00711/0.00609. Took 4.32 sec
# Epoch 90, Acc(train/val): 2.77/2.72, Loss(train/val) 0.00698/0.00662. Took 4.33 sec
# Epoch 91, Acc(train/val): 2.75/2.63, Loss(train/val) 0.00710/0.00586. Took 4.33 sec
# Epoch 92, Acc(train/val): 2.77/2.88, Loss(train/val) 0.00712/0.00591. Took 4.32 sec
# Epoch 93, Acc(train/val): 2.77/2.78, Loss(train/val) 0.00706/0.00606. Took 4.31 sec
# Epoch 94, Acc(train/val): 2.74/2.65, Loss(train/val) 0.00700/0.00598. Took 4.32 sec
# Epoch 95, Acc(train/val): 2.78/2.66, Loss(train/val) 0.00706/0.00589. Took 4.34 sec
# Epoch 96, Acc(train/val): 2.78/2.80, Loss(train/val) 0.00706/0.00597. Took 4.31 sec
# Epoch 97, Acc(train/val): 2.79/2.60, Loss(train/val) 0.00710/0.00600. Took 4.31 sec
# Epoch 98, Acc(train/val): 2.75/2.62, Loss(train/val) 0.00701/0.00590. Took 4.33 sec
# Epoch 99, Acc(train/val): 2.76/2.77, Loss(train/val) 0.00702/0.00594. Took 4.32 sec

# %%
var1 = 'lr'
var2 = 'n_layers'
df = load_exp_result('exp4')

plot_acc(var1, var2, df)
plot_loss_variation(var1, var2, df, sharey=True) #sharey를 True로 하면 모둔 subplot의 y축의 스케일이 같아집니다.
plot_acc_variation(var1, var2, df, margin_titles=True, sharey=True)
